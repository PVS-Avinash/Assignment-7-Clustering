# %%
import pandas as pd
import numpy as np
import seaborn as sn
from matplotlib import pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
ewa=pd.read_excel("EastWestAirlines.xlsx",'data')

# %%
ewa.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
ewa.tail()
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?
# 3994       1
# 3995       1
# 3996       1
# ...

# %%
ewa.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
ewa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
ewa.shape
# Out:
# (3999, 12)

# %%
ewa.dtypes
# Out:
# ID#                  int64
# Balance              int64
# Qual_miles           int64
# cc1_miles            int64
# cc2_miles            int64
# cc3_miles            int64
# Bonus_miles          int64
# Bonus_trans          int64
# Flight_miles_12mo    int64
# Flight_trans_12      int64
# Days_since_enroll    int64
# Award?               int64
# dtype: object

# %%
ewa.isna().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
ewa.duplicated().value_counts()
# Out:
# False    3999
# dtype: int64

# %%
ewa1=ewa.drop('ID#',axis=1)
ewa1.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
stdscaler=StandardScaler()
ewascaler=stdscaler.fit_transform(ewa1)
ewascaler=pd.DataFrame(ewascaler,columns=['Balance','Qual_miles','cc1_miles','cc2_miles','cc3_miles','Bonus_miles','Bonus_trans','Flight_miles_12mo','Flight_trans_12','Days_since_enroll','Award?'])
ewascaler.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4  0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0    -1.104065          -0.328603        -0.362168           1.395454
# 1    -0.999926          -0.328603        -0.362168           1.379957
# 2    -0.791649          -0.328603        -0.362168           1.411920
# 3    -1.104065          -0.328603        -0.362168           1.372208
# 4     1.499394           1.154932         0.692490           1.363975
#
#      Award?
# 0 -0.766919
# 1 -0.766919
# 2 -0.766919
# 3 -0.766919
# 4  1.303918

# %%
Dm=DBSCAN(eps=0.8,min_samples=6)
Dm.fit(ewascaler)
# Out:
# DBSCAN(eps=0.8, min_samples=6)

# %%
y_DB=Dm.fit_predict(ewascaler)
y_DB
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
ewac=pd.DataFrame(y_DB,columns=['clusters'])
ewac.head()
# Out:
#    clusters
# 0         0
# 1         0
# 2         0
# 3         0
# 4        -1

# %%
ewa['clusters']=ewac
ewa['clusters'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4   -1
# Name: clusters, dtype: int64

# %%
ewa['clusters'].value_counts()
# Out:
#  0    2216
#  1     944
# -1     820
#  2      12
#  3       7
# Name: clusters, dtype: int64

# %%
ewa[ewa['clusters']==-1]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4        5    97752           0          4          1          1        43300
# 8        9   443003           0          3          2          1         1753
# 9       10   104860           0          3          1          1        28426
# 21      22   185681        2024          1          1          1        13300
# 22      23    20584           0          1          1          1         3450
# ...    ...      ...         ...        ...        ...        ...          ...
# 3953  3976    59927         739          1          1          1         3100
# 3954  3977    33972           0          3          1          1        21029
# 3956  3979    47301        1005          1          1          1         4561
# 3961  3984   131125         862          1          1          1         4993
# 3967  3990    26504           0          2          1          1        10599
#
# ...

# %%
ewa[ewa['clusters']==0]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3990  4013    11310           0          1          1          1         5021
# 3992  4015    11181           0          1          1          1          929
# 3993  4016     3974           0          1          1          1          365
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
ewa[ewa['clusters']==1]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 7        8    20856           0          1          1          1         5250
# 11      12    96522           0          5          1          1        61105
# 15      16    28495           0          4          1          1        49442
# 16      17    51890           0          4          1          1        48963
# 17      18    13958           0          1          1          1         4291
# ...    ...      ...         ...        ...        ...        ...          ...
# 3987  4010    11933           0          1          1          1          249
# 3989  4012     2622           0          1          1          1         1625
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
#
# ...

# %%
ewa[ewa['clusters']==2]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 794    804    55610           0          1          2          1         5095
# 1149  1161    84856           0          1          2          1         6894
# 1541  1556    36887           0          1          2          1         9048
# 1976  1993    11961           0          1          2          1        11961
# 2317  2335    10458           0          1          2          1        10458
# 2421  2440    41062           0          1          2          1         8275
# 2741  2763    42970           0          1          2          1         7889
# 2906  2928    17769           0          1          2          1         5165
# 3155  3177    21736           0          1          2          1         6672
# 3191  3213    56624           0          1          2          1        12311
# 3359  3382    20318           0          1          2          1         6990
# ...

# %%
ewa[ewa['clusters']==3]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3569  3592    48607           0          3          1          1        18284
# 3601  3624    74093           0          3          1          1        20055
# 3619  3642    46207           0          3          1          1        16093
# 3860  3883    35650           0          3          1          1        23130
# 3974  3997    58387           0          3          1          1        14581
# 3980  4003    28867           0          3          1          1        19169
# 3991  4014    39142           0          3          1          1        14981
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3569           37                  0                0               1339
# 3601           37                  0                0                949
# 3619           32                  0                0               1130
# ...

# %%
ewa[ewa['clusters']==4]
# Out:
# Empty DataFrame
# Columns: [ID#, Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award?, clusters]
# Index: []

# %%
ewa[ewa['clusters']==5]
# Out:
# Empty DataFrame
# Columns: [ID#, Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award?, clusters]
# Index: []

# %%
ewa.groupby(by='clusters').agg(['mean']).reset_index()
# Out:
#   clusters          ID#        Balance  Qual_miles cc1_miles cc2_miles  \
#                    mean           mean        mean      mean      mean
# 0       -1  1744.781707  158564.875610  698.553659  2.670732  1.056098
# 1        0  2185.088899   50589.121390    0.676895  1.629964  1.000000
# 2        1  1830.398305   54510.457627    2.118644  2.543432  1.000000
# 3        2  2477.833333   34516.083333    0.000000  1.000000  2.000000
# 4        3  3822.142857   47279.000000    0.000000  3.000000  1.000000
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.059756  35956.408537   20.157317       1805.067073        5.232927
# 1  1.000000   8534.324458    8.112365         85.902978        0.291065
# 2  1.000000  21126.111229   12.194915        179.287076        0.590042
# 3  1.000000   8048.333333   11.916667          0.000000        0.000000
# ...

# %%
plt.figure(figsize=(10,5))
sn.scatterplot(ewa['clusters'],ewa['ID#'],c=Dm.labels_)
plt.show
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>
